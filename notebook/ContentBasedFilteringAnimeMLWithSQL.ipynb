# %%
import pandas as pd
import numpy as np
import mysql.connector as mysql

from mysql.connector import Error
from getpass import getpass
from scipy.sparse import csr_matrix, load_npz
from sklearn.neighbors import NearestNeighbors

def connections(host='localhost', user='root', password=getpass()):
    try:
        print("Success connect to MySQL!")
        return mysql.connect(host=host, user=user, password=password)
    except:
        print("Error connecting to MySQL")

def connect_to_db(conn, db_name):
    try:
        if conn.is_connected():
            cursor = conn.cursor()
            cursor.execute(f"create database if not exists {db_name};")
            print(f"Database: {db_name} is created")
            cursor.execute(f"use {db_name};")
            print(f"You're connected to database: {db_name}")
            return
    except Error as e:
        print("Error while connecting to MySQL", e)
conn = connections()
# Out:
# Success connect to MySQL!

# %%
anime = pd.read_sql(sql="select * from animedb.anime;", con=conn, index_col='animeIndex')
anime.index = anime.index - 1
anime_metadata = np.load("../data/binary/anime_metadata.npy")
animeFeaturesTfidf = load_npz("../data/binary/animeFeaturesTfidf.npz")

# %%
# Out:
# True

# %%
def animeSearch(df_, nameQuery, n=5, sortByScore=True):
    df = df_.copy()
    nameQuery = nameQuery.lower()

    nameContains = df.loc[df.animeNameLower.str.contains(nameQuery, na=False)].drop(columns=['animeFeatures',
                                                                                         'animeNameLower'])

    if sortByScore:
        nameContains = nameContains.sort_values(by="animeScore", ascending=False)

    if n in ['all', 'All']:
        pd.set_option('display.max_rows', len(nameContains))
    else:
        pd.set_option('display.max_rows', n)
        nameContains = nameContains[:n]
        return nameContains
    return nameContains


def getSimilar(df=anime, vector=None, query_index=None, n=50):
    model_knn = NearestNeighbors(metric='cosine', n_neighbors=n)
    model_knn.fit(csr_matrix(vector.astype(np.float)))

    distances, indices = model_knn.kneighbors(
        vector[query_index, :].reshape(1, -1), n_neighbors=n)
    result, score = [], []
    for i in range(0, len(distances.flatten())):
        index = indices.flatten()[i]
        if index == query_index:
            continue
        result.append(df.iloc[index])
    results_df = pd.DataFrame(result)#.sort_values(by="Score", ascending=False)
    pd.set_option('display.max_rows', len(results_df))
    return results_df


def mostSimilarByIndex(mal_id, n=50, showAll=True):
    query = anime[anime.MAL_ID == mal_id]
    query_index = query.index
    vectorMeta = anime_metadata
    vectorSynop = animeFeaturesTfidf
    Meta = getSimilar(
        df=anime, vector=vectorMeta, query_index=query_index, n=n)
    Synop = getSimilar(
        df=anime, vector=vectorSynop, query_index=query_index, n=n)
    MetaSynop = Synop.append(Meta)
    MetaSynop = MetaSynop.drop_duplicates().sort_values(by="animeScore", ascending=False)
    MetaSynop = MetaSynop.drop(columns=['animeFeatures'])
    if showAll:
        pd.set_option('display.max_rows', len(MetaSynop))
        print(
            f"Generated total dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
        return MetaSynop
    pd.set_option('display.max_rows', 10)
    print(
        f"Generated dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
    return MetaSynop

def mostSimilarByName(name, n=50, showAll=True):
    query = animeSearch(nameQuery=name, df_=anime, n=1, sortByScore=False)
    query_index = query.index
    vectorMeta = anime_metadata
    vectorSynop = animeFeaturesTfidf
    Meta = getSimilar(
        df=anime, vector=vectorMeta, query_index=query_index, n=n)
    Synop = getSimilar(
        df=anime, vector=vectorSynop, query_index=query_index, n=n)
    MetaSynop = Synop.append(Meta)
    MetaSynop = MetaSynop.drop_duplicates().sort_values(by="animeScore", ascending=False)
    MetaSynop = MetaSynop.drop(columns=['animeFeatures'])
    if showAll:
        pd.set_option('display.max_rows', len(MetaSynop))
        print(
            f"Generated total dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
        return query, MetaSynop
    pd.set_option('display.max_rows', 10)
    print(
        f"Generated dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
    return query, MetaSynop

# %%
animeResults = animeSearch(anime, nameQuery="Jojo", n=1)
animeResults
# Out:
#             animeID                                       animeName  \
# animeIndex
# 13402         37991  JoJo no Kimyou na Bouken Part 5: Ougon no Kaze
#
#             animeScore                 animeGenres  \
# animeIndex
# 13402             8.61  Action, Adventure, Shounen
#
#                                                 animeSynopsis animeType  \
# animeIndex
# 13402       In the coastal city of Naples, corruption is t...        TV
#
#             animeEpisodes animePremiered      animeStudios animeSource  \
# animeIndex
# 13402                  39      Fall 2018  David Production       Manga
#
#                                animeRating  animeRanked  animePopularity  \
# animeIndex
# 13402       R - 17+ (violence & profanity)           63              211
#
#             animeFavorites
# animeIndex
# 13402                21884

# %%
real, predicted = mostSimilarByName('Jojo', n=20)
# Out:
# Generated total dataframe with 37 rows and 15 columns

# %%
real
# Out:
#             animeID                            animeName  animeScore  \
# animeIndex
# 609             665  JoJo no Kimyou na Bouken: Adventure        7.18
#
#                                                   animeGenres  \
# animeIndex
# 609         Adventure, Drama, Fantasy, Horror, Shounen, Su...
#
#                                                 animeSynopsis animeType  \
# animeIndex
# 609         Kujo Jotaro is a normal, popular Japanese high...       OVA
#
#             animeEpisodes animePremiered animeStudios animeSource  \
# animeIndex
# 609                     7        Unknown         APPP       Manga
#
#                  animeRating  animeRanked  animePopularity  animeFavorites
# animeIndex
# 609         R+ - Mild Nudity         2855             2102             338

# %%
predicted
# Out:
#        animeID                                          animeName  animeScore  \
# 10021    31758                   Kizumonogatari III: Reiketsu-hen        8.82
# 26          44  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...        8.73
# 10020    31757                    Kizumonogatari II: Nekketsu-hen        8.61
# 13402    37991     JoJo no Kimyou na Bouken Part 5: Ougon no Kaze        8.61
# 10092    31933  JoJo no Kimyou na Bouken Part 4: Diamond wa Ku...        8.51
# 8426     26055  JoJo no Kimyou na Bouken Part 3: Stardust Crus...        8.45
# 2282      2685                         Tsubasa: Tokyo Revelations        8.31
# 2879      3702                                 Detroit Metal City        8.14
# 7397     20899  JoJo no Kimyou na Bouken Part 3: Stardust Crus...        8.12
# 7917     23317                       Kuroshitsuji: Book of Murder        8.12
# 747        851                                 Kyou kara Ore wa!!        8.07
# 6290     14719                      JoJo no Kimyou na Bouken (TV)        8.06
# 237        268                                         Golden Boy        8.03
# 367        401  Rurouni Kenshin: Meiji Kenkaku Romantan - Seis...        8.00
# 3349      4872                      Goku Sayonara Zetsubou Sensei        7.85
# 4909      9088                                    Saiyuuki Gaiden        7.84
# 4210      7044             Zan Sayonara Zetsubou Sensei Bangaichi        7.80
# 2827      3603            JoJo no Kimyou na Bouken: Phantom Blood        7.71
# 10561    33032                          Drifters: Special Edition        7.70
# 4146      6904                        Hellsing: Digest for Freaks        7.67
# 12461    36480                                     Drifters (OVA)        7.57
# 10653    33191                          Kishibe Rohan wa Ugokanai        7.56
# 3507      5251                                     Angel Densetsu        7.50
# 8193     24781                       Imawa no Kuni no Alice (OVA)        7.47
# 10315    32574      Kekkai Sensen: Ousama no Restaurant no Ousama        7.40
# 3164      4312                            Hokuto no Ken: Toki-den        7.40
# 3617      5593                            Dogs: Bullets & Carnage        7.34
# 10119    32015                                           Ajin OVA        7.25
# 609        665                JoJo no Kimyou na Bouken: Adventure        7.18
# 10019    31756          Owari no Seraph: The Beginning of the End        7.16
# 13407    37997                      Devils Line: Anytime Anywhere        6.87
# 6461     15933                                         Vassalord.        6.85
# 14005    38972  JoJo no Kimyou na Bouken Part 5: Ougon no Kaze...        6.74
# 4544      8146                       Gegege no Kitarou: Daikaijuu        6.22
# 3651      5689                                     Eien no Filena        5.80
# 1514      1740  Naikaku Kenryoku Hanzai Kyousei Torishimarikan...        5.51
# 11782    35266                                 Higanjima X: Aniki        0.00
#
#                                              animeGenres  \
# 10021             Action, Mystery, Supernatural, Vampire
# 26     Action, Historical, Drama, Romance, Martial Ar...
# 10020             Action, Mystery, Supernatural, Vampire
# 13402                         Action, Adventure, Shounen
# 10092  Action, Adventure, Comedy, Supernatural, Drama...
# 8426     Action, Adventure, Supernatural, Drama, Shounen
# 2282   Action, Adventure, Drama, Romance, Fantasy, Sh...
# 2879                               Music, Comedy, Seinen
# 7397     Action, Adventure, Supernatural, Drama, Shounen
# 7917   Action, Mystery, Comedy, Historical, Demons, S...
# 747                                      Comedy, Shounen
# 6290   Action, Adventure, Supernatural, Vampire, Shounen
# 237                             Adventure, Comedy, Ecchi
# 367         Romance, Samurai, Historical, Drama, Shounen
# 3349                     Comedy, Parody, School, Shounen
# 4909                   Action, Adventure, Drama, Fantasy
# 4210                     Comedy, Parody, School, Shounen
# 2827         Action, Adventure, Horror, Shounen, Vampire
# 10561  Action, Adventure, Comedy, Fantasy, Historical...
# 4146   Action, Horror, Military, Seinen, Super Power,...
# 12461  Action, Adventure, Comedy, Fantasy, Historical...
# 10653             Action, Mystery, Supernatural, Shounen
# 3507                              Action, Comedy, School
# 8193   Action, Psychological, Supernatural, Thriller,...
# 10315  Action, Comedy, Super Power, Supernatural, Fan...
# 3164                                Action, Martial Arts
# 3617                                      Action, Seinen
# 10119      Action, Mystery, Horror, Supernatural, Seinen
# 609    Adventure, Drama, Fantasy, Horror, Shounen, Su...
# 10019      Action, Drama, Shounen, Supernatural, Vampire
# 13407  Action, Supernatural, Drama, Romance, Vampire,...
# 6461   Action, Comedy, Fantasy, Mystery, Shounen Ai, ...
# 14005                         Action, Adventure, Shounen
# 4544      Action, Fantasy, Horror, Shounen, Supernatural
# 3651                           Adventure, Drama, Fantasy
# 1514                       Action, Police, Drama, Seinen
# 11782                   Fantasy, Horror, Seinen, Vampire
#
#                                            animeSynopsis animeType  \
# 10021  fter helping revive the legendary vampire Kiss...     Movie
# 26     hen mankind's savagery surpasses his fear of d...       OVA
# 10020  No longer truly human, Koyomi Araragi decides ...     Movie
# 13402  In the coastal city of Naples, corruption is t...        TV
# 10092  The year is 1999. Morioh, a normally quiet and...        TV
# 8426   Joutarou Kuujou and his allies have finally ma...        TV
# 2282   Continuing their journey from Record Country (...       OVA
# 2879   Dominating the world of indie music, Detroit M...       OVA
# 7397   Years after an ancient evil was salvaged from ...        TV
# 7917   he behest of the Queen, Earl Ciel Phantomhive ...       OVA
# 747    Two transfer students, Mitsuhashi Takashi and ...       OVA
# 6290   In 1868, Dario Brando saves the life of an Eng...        TV
# 237    Kintarou Ooe is a specialist in part-time work...       OVA
# 367    Kaoru goes to the harbor every day to see if K...       OVA
# 3349                       Sayonara Zetsubou Sensei OVA.       OVA
# 4909   OVA adaptation of the climactic part of Saiyuu...       OVA
# 4210                       Sayonara Zetsubou Sensei OVA.       OVA
# 2827   adaptation of the original five volume arc of ...     Movie
# 10561               Bundled with the fifth manga volume.       OVA
# 4146   This OVA is a summary of the first three episo...       OVA
# 12461  Despite the Ends’ attack on Verlina being succ...       OVA
# 10653  ohan Kishibe accompanies Kyouka Izumi, a manga...       OVA
# 3507   hen Seikichi Kuroda—self-proclaimed "guardian"...       OVA
# 8193   ouhei Arisu is a high school student with no a...       OVA
# 10315  The Winter 2016 issue of Jump SQ.Crown magazin...       OVA
# 3164   The fourth part of the new Hokuto no Ken penta...       OVA
# 3617   It is sometime in the future, where a certain ...       OVA
# 10119  New episodes bundled with the limited edition ...       OVA
# 609    Kujo Jotaro is a normal, popular Japanese high...       OVA
# 10019  cap of 1st Season Aired Before Nagoya Kessen-h...   Special
# 13407  Bundled with the limited edition of the manga'...       OVA
# 6461   Charley, a cyborg vampire who does the Vatican...       OVA
# 14005  caps of the JoJo no Kimyou na Bouken: Ougon no...   Special
# 4544   ovie based on the 1996 TV anime with an origin...     Movie
# 3651   The story is centered around Filena, a princes...       OVA
# 1514   Based on Ken Kitashiba & Yasuhiro Watanabe's p...        TV
# 11782  pisode of Higanjima X that was included in Blu...   Special
#
#        animeEpisodes animePremiered           animeStudios  animeSource  \
# 10021              1        Unknown                  Shaft  Light novel
# 26                 4        Unknown            Studio Deen        Manga
# 10020              1        Unknown                  Shaft  Light novel
# 13402             39      Fall 2018       David Production        Manga
# 10092             39    Spring 2016       David Production        Manga
# 8426              24    Winter 2015       David Production        Manga
# 2282               3        Unknown         Production I.G        Manga
# 2879              12        Unknown             Studio 4°C        Manga
# 7397              24    Spring 2014       David Production        Manga
# 7917               2        Unknown           A-1 Pictures        Manga
# 747               10        Unknown         Studio Pierrot        Manga
# 6290              26      Fall 2012       David Production        Manga
# 237                6        Unknown                   APPP        Manga
# 367                2        Unknown            Studio Deen        Manga
# 3349               3        Unknown                  Shaft        Manga
# 4909               3        Unknown                Unknown        Manga
# 4210               2        Unknown                  Shaft        Manga
# 2827               1        Unknown                   APPP        Manga
# 10561              1        Unknown  Hoods Drifters Studio        Manga
# 4146               1        Unknown              Satelight        Manga
# 12461              2        Unknown  Hoods Drifters Studio        Manga
# 10653              4        Unknown       David Production        Manga
# 3507               2        Unknown         Toei Animation        Manga
# 8193               3        Unknown  SILVER LINK., Connect        Manga
# 10315              1        Unknown                  Bones        Manga
# 3164               1        Unknown                   APPP      Unknown
# 3617               4        Unknown       David Production        Manga
# 10119              2        Unknown       Polygon Pictures        Manga
# 609                7        Unknown                   APPP        Manga
# 10019              1        Unknown             Wit Studio        Manga
# 13407              1        Unknown        Platinum Vision        Manga
# 6461               1        Unknown         Production I.G        Manga
# 14005              3        Unknown       David Production        Manga
# 4544               1        Unknown         Toei Animation      Unknown
# 3651               6        Unknown         Studio Pierrot  Light novel
# 1514              11    Summer 2006             Trans Arts        Manga
# 11782              1        Unknown                Unknown        Manga
#
#                           animeRating  animeRanked  animePopularity  \
# 10021  R - 17+ (violence & profanity)           23              448
# 26     R - 17+ (violence & profanity)           37              637
# 10020  R - 17+ (violence & profanity)           64              460
# 13402  R - 17+ (violence & profanity)           63              211
# 10092  R - 17+ (violence & profanity)          100              163
# 8426   R - 17+ (violence & profanity)          122              159
# 2282   R - 17+ (violence & profanity)          225             1628
# 2879   R - 17+ (violence & profanity)          372              847
# 7397   R - 17+ (violence & profanity)          390              136
# 7917   R - 17+ (violence & profanity)          395              822
# 747    R - 17+ (violence & profanity)          455             3419
# 6290   R - 17+ (violence & profanity)          463               74
# 237                  R+ - Mild Nudity          507              579
# 367    R - 17+ (violence & profanity)          542             1795
# 3349   R - 17+ (violence & profanity)          739             2081
# 4909   R - 17+ (violence & profanity)          764             4693
# 4210   R - 17+ (violence & profanity)          830             2765
# 2827   R - 17+ (violence & profanity)         1000             2403
# 10561  R - 17+ (violence & profanity)         1022             3116
# 4146   R - 17+ (violence & profanity)         1109             2748
# 12461  R - 17+ (violence & profanity)         1367             1984
# 10653  R - 17+ (violence & profanity)         1391             2262
# 3507   R - 17+ (violence & profanity)         1568             3170
# 8193   R - 17+ (violence & profanity)         1685             2705
# 10315  R - 17+ (violence & profanity)         1903             2864
# 3164   R - 17+ (violence & profanity)         1913             5743
# 3617   R - 17+ (violence & profanity)         2145             2103
# 10119  R - 17+ (violence & profanity)         2562             2597
# 609                  R+ - Mild Nudity         2855             2102
# 10019  R - 17+ (violence & profanity)         2957             2462
# 13407  R - 17+ (violence & profanity)         4145             4424
# 6461   R - 17+ (violence & profanity)         4249             3103
# 14005  R - 17+ (violence & profanity)         4720             3350
# 4544                     G - All Ages         7244            10779
# 3651   R - 17+ (violence & profanity)         8827            10527
# 1514   R - 17+ (violence & profanity)         9654            10055
# 11782  R - 17+ (violence & profanity)        14400            13895
#
#        animeFavorites                                     animeNameLower
# 10021            4898                   kizumonogatari iii: reiketsu-hen
# 26               6111  rurouni kenshin: meiji kenkaku romantan - tsui...
# 10020            1847                    kizumonogatari ii: nekketsu-hen
# 13402           21884     jojo no kimyou na bouken part 5: ougon no kaze
# 10092           23817  jojo no kimyou na bouken part 4: diamond wa ku...
# 8426            13852  jojo no kimyou na bouken part 3: stardust crus...
# 2282              899                         tsubasa: tokyo revelations
# 2879             3100                                 detroit metal city
# 7397            14056  jojo no kimyou na bouken part 3: stardust crus...
# 7917             1217                       kuroshitsuji: book of murder
# 747               285                                 kyou kara ore wa!!
# 6290            26522                      jojo no kimyou na bouken (tv)
# 237              3784                                         golden boy
# 367               400  rurouni kenshin: meiji kenkaku romantan - seis...
# 3349              100                      goku sayonara zetsubou sensei
# 4909               66                                    saiyuuki gaiden
# 4210               38             zan sayonara zetsubou sensei bangaichi
# 2827              619            jojo no kimyou na bouken: phantom blood
# 10561              24                          drifters: special edition
# 4146               85                        hellsing: digest for freaks
# 12461              75                                     drifters (ova)
# 10653             116                          kishibe rohan wa ugokanai
# 3507              119                                     angel densetsu
# 8193              104                       imawa no kuni no alice (ova)
# 10315              23      kekkai sensen: ousama no restaurant no ousama
# 3164               10                            hokuto no ken: toki-den
# 3617              275                            dogs: bullets & carnage
# 10119              28                                           ajin ova
# 609               338                jojo no kimyou na bouken: adventure
# 10019             106          owari no seraph: the beginning of the end
# 13407              23                      devils line: anytime anywhere
# 6461               98                                         vassalord.
# 14005             302  jojo no kimyou na bouken part 5: ougon no kaze...
# 4544                0                       gegege no kitarou: daikaijuu
# 3651                1                                     eien no filena
# 1514                2  naikaku kenryoku hanzai kyousei torishimarikan...
# 11782               0                                 higanjima x: aniki

# %%
mostSimilarByIndex(query_index=10213, n=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17328/2853685918.py in <module>
# ----> 1 mostSimilarByIndex(query_index=10213, n=20)
#
# TypeError: mostSimilarByIndex() got an unexpected keyword argument 'query_index'
