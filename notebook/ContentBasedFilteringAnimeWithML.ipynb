# %%
import re
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from scipy.sparse import csr_matrix, save_npz
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer, MinMaxScaler

# %%
# Reading anime with synopsis
animeSynopsis = pd.read_csv("../data/raw/anime_with_synopsis.csv").rename(columns={'sypnopsis': 'Synopsis'})

# Cleaning anime with synopsis
animeSynopsis['MAL_ID'] = animeSynopsis['MAL_ID'].replace("Unknown", 0).fillna(0).astype('int64')
animeSynopsis['Score'] = animeSynopsis['Score'].replace("Unknown", 0).fillna(0).astype('float64')
animeSynopsis = animeSynopsis.fillna("Unknown")

# Reading anime list
useCols = ['MAL_ID', 'Type', 'Popularity', 'Favorites', 'Ranked', 'Episodes', 'Rating', 'Premiered', 'Studios', 'Source']

animeList = pd.read_csv("../data/raw/anime.csv", usecols=useCols)

# Cleaning anime list
animeList['Ranked'] = animeList['Ranked'].replace("Unknown", 0).fillna(0).astype('float64')
animeList['MAL_ID'] = animeList['MAL_ID'].replace("Unknown", 0).fillna(0).astype('int64')
animeList['Episodes'] = animeList['Episodes'].replace("Unknown", 0).fillna(0).astype('int64')
animeList['Favorites'] = animeList['Favorites'].replace("Unknown", 0).fillna(0).astype('int64')
animeList['Popularity'] = animeList['Popularity'].replace("Unknown", 0).fillna(0).astype('int64')
animeList = animeList.fillna("Unknown")

# Merge animeList dataframe and animeSynopsis dataframe
anime = pd.merge(animeSynopsis, animeList, on='MAL_ID')

# source: https://www.kaggle.com/indralin/try-content-based-and-collaborative-filtering
# Cleaning text
def text_cleaning(text):
    stopword = set(stopwords.words('english'))
    text = text.lower()
    text = re.sub(r'&quot;', '', text)
    text = re.sub(r'.hack//', '', text)
    text = re.sub(r'&#039;', '', text)
    text = re.sub(r'A&#039;s', '', text)
    text = re.sub(r'I&#039;', 'I\'', text)
    text = re.sub(r'&amp;', 'and', text)
    text = re.sub('[/(){}\[\]\|@,;]', ' ', text)
    text = re.sub('[^0-9a-z #+_]', '', text)
    text = ' '.join(word for word in text.split() if word not in stopword)
    return text

useCols = ["Genres", "Name", "Type", "Source", "Rating", "Premiered", "Studios"]
anime["Features"] = anime["Synopsis"].str.cat(anime[useCols], sep=" ")
anime["Features"] = anime["Features"].apply(text_cleaning)
anime["name_lower"] = anime["Name"].apply(lambda x: x.lower())

anime.to_csv('../data/dataset/anime_clean.csv', index=False)

print(anime.shape)
anime.head(2)
# Out:
# (16214, 16)
#    MAL_ID                             Name  Score  \
# 0       1                     Cowboy Bebop   8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira   8.39
#
#                                             Genres  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1            Action, Drama, Mystery, Sci-Fi, Space
#
#                                             Synopsis   Type  Episodes  \
# 0  In the year 2071, humanity has colonized sever...     TV        26
# 1  other day, another bounty—such is the life of ...  Movie         1
#
#      Premiered  Studios    Source                          Rating  Ranked  \
# 0  Spring 1998  Sunrise  Original  R - 17+ (violence & profanity)    28.0
# 1      Unknown    Bones  Original  R - 17+ (violence & profanity)   159.0
#
#    Popularity  Favorites                                           Features  \
# 0          39      61971  year 2071 humanity colonized several planets m...
# 1         518       1174  day another bountysuch life often unlucky crew...
#
#                         name_lower
# 0                     cowboy bebop
# 1  cowboy bebop: tengoku no tobira

# %%
def preprocessing_category(df, column, is_multilabel=False):
    # Binarise labels
    lb = LabelBinarizer()
    if is_multilabel:
        lb = MultiLabelBinarizer()
    expandedLabelData = lb.fit_transform(df[column])
    labelClasses = lb.classes_

    # Create a pandas.DataFrame from our output
    category_df = pd.DataFrame(expandedLabelData, columns=labelClasses)
    del df[column]
    return pd.concat([df, category_df], axis=1)

# %%
# Using anime metadata to filtering content

anime_metadata = anime.copy()

del anime_metadata['Features']
del anime_metadata['Name']
del anime_metadata['Genres']
del anime_metadata['name_lower']
del anime_metadata['Synopsis']
del anime_metadata['MAL_ID']

catCols = anime_metadata.select_dtypes(exclude=['int64', 'float64']).columns
numCols = anime_metadata.select_dtypes(exclude=['object']).columns

for col in catCols:
    anime_metadata = preprocessing_category(anime_metadata, col)

anime_metadata[numCols] =  MinMaxScaler().fit_transform(anime_metadata[numCols])
anime_metadata = anime_metadata.values
print(anime_metadata.shape)

np.save("../data/binary/anime_metadata.npy", anime_metadata)
# Out:
# (16214, 1303)

# %%
# Using tf-idf to encode based from synopsis, name and genre to filtering content

matVet = TfidfVectorizer(stop_words='english', 
                         analyzer='word', 
                         ngram_range=(1,3), 
                         min_df=3,
                         strip_accents='unicode',
                         max_features=None,
                         token_pattern=r'\w{1,}') # currently only support english, and analyze based on word (since this is document dataset)

animeFeatures = anime['Features'].copy()
animeFeaturesTfidf = matVet.fit_transform(animeFeatures)

save_npz("../data/binary/animeFeaturesTfidf.npz", animeFeaturesTfidf)

animeFeaturesTfidf.shape
# Out:
# (16214, 52594)

# %%
def animeSearch(df_, nameQuery, n=5, sortByScore=True):
    df = df_.copy()
    nameQuery = nameQuery.lower()
    df["name_lower"] = df["Name"].apply(lambda x: x.lower())

    nameContains = df.loc[df.name_lower.str.contains(nameQuery, na=False)].drop(columns=['Features',
                                                                                         'name_lower'])

    if sortByScore:
        nameContains = nameContains.sort_values(by="Score", ascending=False)

    if n in ['all', 'All']:
        pd.set_option('display.max_rows', len(nameContains))
    else:
        pd.set_option('display.max_rows', n)
        nameContains = nameContains[:n]
        return nameContains
    return nameContains


def getSimilar(df=anime, vector=None, query_index=None, n=50):
    model_knn = NearestNeighbors(metric='cosine', n_neighbors=n)
    model_knn.fit(csr_matrix(vector.astype(np.float)))

    distances, indices = model_knn.kneighbors(
        vector[query_index, :].reshape(1, -1), n_neighbors=n)
    result, score = [], []
    for i in range(0, len(distances.flatten())):
        index = indices.flatten()[i]
        if index == query_index:
            continue
        result.append(df.iloc[index])
    results_df = pd.DataFrame(result)#.sort_values(by="Score", ascending=False)
    pd.set_option('display.max_rows', len(results_df))
    return results_df


def mostSimilarByIndex(query_index, n=50, showAll=True):
    vectorMeta = anime_metadata
    vectorSynop = animeFeaturesTfidf
    Meta = getSimilar(
        df=anime, vector=vectorMeta, query_index=query_index, n=n)
    Synop = getSimilar(
        df=anime, vector=vectorSynop, query_index=query_index, n=n)
    MetaSynop = Synop.append(Meta)
    MetaSynop = MetaSynop.drop_duplicates().sort_values(by="Score", ascending=False)
    MetaSynop = MetaSynop.drop(columns=['Features'])
    if showAll:
        pd.set_option('display.max_rows', len(MetaSynop))
        print(
            f"Generated total dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
        return MetaSynop
    pd.set_option('display.max_rows', 10)
    print(
        f"Generated dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
    return MetaSynop

def mostSimilarByName(name, n=50, showAll=True):
    query = animeSearch(nameQuery=name, df_=anime, n=1, sortByScore=False)
    query_index = query.index
    vectorMeta = anime_metadata
    vectorSynop = animeFeaturesTfidf
    Meta = getSimilar(
        df=anime, vector=vectorMeta, query_index=query_index, n=n)
    Synop = getSimilar(
        df=anime, vector=vectorSynop, query_index=query_index, n=n)
    MetaSynop = Synop.append(Meta)
    MetaSynop = MetaSynop.drop_duplicates().sort_values(by="Score", ascending=False)
    MetaSynop = MetaSynop.drop(columns=['Features'])
    if showAll:
        pd.set_option('display.max_rows', len(MetaSynop))
        print(
            f"Generated total dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
        return query, MetaSynop
    pd.set_option('display.max_rows', 10)
    print(
        f"Generated dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
    return query, MetaSynop

# %%
animeResults = animeSearch(anime, nameQuery="chuunibyou", n=5)
animeResults
# Out:
# Generated dataframe with 5 rows and 14 columns
#        MAL_ID                                               Name  Score  \
# 11986   35608   Chuunibyou demo Koi ga Shitai! Movie: Take On Me   8.15
# 6291    14741                     Chuunibyou demo Koi ga Shitai!   7.77
# 7010    18671                 Chuunibyou demo Koi ga Shitai! Ren   7.56
# 6658    16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......   7.51
# 8592    27601  Chuunibyou demo Koi ga Shitai! Ren: The Rikka ...   7.47
#
#                                               Genres  \
# 11986  Comedy, Drama, Romance, School, Slice of Life
# 6291   Slice of Life, Comedy, Drama, Romance, School
# 7010   Comedy, Drama, Romance, School, Slice of Life
# 6658   Comedy, Drama, Romance, School, Slice of Life
# 8592   Comedy, Drama, Romance, School, Slice of Life
#
#                                                 Synopsis     Type  Episodes  \
# 11986  lthough already a third-year high school stude...    Movie         1
# 6291   Everybody has had that stage in their life whe...       TV        12
# 7010   The awkward lovebirds, Yuuta Togashi and Rikka...       TV        12
# 6658   lthough Yuuta Togashi and Rikka Takanashi have...  Special         1
# 8592   One normal school day, Rikka Takanashi notices...  Special         1
#
#          Premiered          Studios       Source                     Rating  \
# 11986      Unknown  Kyoto Animation  Light novel  PG-13 - Teens 13 or older
# 6291     Fall 2012  Kyoto Animation  Light novel  PG-13 - Teens 13 or older
# 7010   Winter 2014  Kyoto Animation  Light novel  PG-13 - Teens 13 or older
# 6658       Unknown  Kyoto Animation  Light novel  PG-13 - Teens 13 or older
# 8592       Unknown  Kyoto Animation  Light novel  PG-13 - Teens 13 or older
#
#        Ranked  Popularity  Favorites
# 11986   356.0         933       1574
# 6291    878.0          77      17973
# 7010   1378.0         226       2952
# 6658   1551.0         901        144
# 8592   1672.0        1519         88

# %%
mostSimilar(query_index=11986, n=20)
# Out:
# Generated total dataframe with 36 rows and 16 columns
#        MAL_ID                                               Name  Score  \
# 13608   38329  Seishun Buta Yarou wa Yumemiru Shoujo no Yume ...   8.68
# 13397   37987                            Violet Evergarden Movie   8.65
# 4286     7311                      Suzumiya Haruhi no Shoushitsu   8.65
# 13439   38040  Kono Subarashii Sekai ni Shukufuku wo!: Kurena...   8.52
# 12728   36885                  Saenai Heroine no Sodatekata Fine   8.48
# 14511   39741  Violet Evergarden Gaiden: Eien to Jidou Shuki ...   8.40
# 13050   37450  Seishun Buta Yarou wa Bunny Girl Senpai no Yum...   8.38
# 5085     9617                                        K-On! Movie   8.33
# 10880   33674                              No Game No Life: Zero   8.32
# 12838   37095  Violet Evergarden: Kitto "Ai" wo Shiru Hi ga K...   8.32
# 12030   35677                                    Liz to Aoi Tori   8.22
# 8813    28675  Kyoukai no Kanata Movie 2: I'll Be Here - Mira...   8.20
# 7536    21647                                  Tamako Love Story   8.00
# 7325    20371  Sekaiichi Hatsukoi Movie: Yokozawa Takafumi no...   7.95
# 9576    30745  Kyoukai no Kanata Movie: I'll Be Here - Kako-h...   7.89
# 9473    30415                   High☆Speed!: Free! Starting Days   7.87
# 6291    14741                     Chuunibyou demo Koi ga Shitai!   7.77
# 8249    25015  Kyoukai no Kanata Movie 1: I'll Be Here - Kako...   7.73
# 7937    23385                       Kyoukai no Kanata: Shinonome   7.67
# 7179    19671                          Free!: FrFr - Short Movie   7.63
# 7010    18671                 Chuunibyou demo Koi ga Shitai! Ren   7.56
# 6658    16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......   7.51
# 8592    27601  Chuunibyou demo Koi ga Shitai! Ren: The Rikka ...   7.47
# 7061    19021  Takanashi Rikka Kai: Chuunibyou demo Koi ga Sh...   7.35
# 602       656                                      Air in Summer   7.33
# 6414    15687                Chuunibyou demo Koi ga Shitai! Lite   7.26
# 12112   35847                                       SSSS.Gridman   7.19
# 7814    22859  Takanashi Rikka Kai: Chuunibyou demo Koi ga Sh...   7.18
# 7566    21797            Chuunibyou demo Koi ga Shitai! Ren Lite   7.17
# 7892    23237        Chuunibyou demo Koi ga Shitai! Ren Specials   7.11
# 12710   36855  Chuunibyou demo Koi ga Shitai! Movie: Take On ...   6.85
# 12911   37207                                    Zuori Qing Kong   6.76
# 6447    15879  Chuunibyou demo Koi ga Shitai!: Depth of Field...   6.72
# 13380   37967  Chuunibyou demo Koi ga Shitai! Movie: Take On ...   6.43
# 6835    17813                        Kyoto Animation: Megane-hen   6.34
# 15920   43556            Tsurune: Kazemai Koukou Kyuudoubu Movie   0.00
#
#                                                   Genres  \
# 13608               Supernatural, Drama, Romance, School
# 13397                      Slice of Life, Drama, Fantasy
# 4286   Comedy, Mystery, Romance, School, Sci-Fi, Supe...
# 13439  Adventure, Comedy, Fantasy, Magic, Parody, Sup...
# 12728              Harem, Comedy, Romance, Ecchi, School
# 14511                      Slice of Life, Drama, Fantasy
# 13050       Comedy, Supernatural, Drama, Romance, School
# 5085                        Music, Slice of Life, Comedy
# 10880        Game, Supernatural, Drama, Romance, Fantasy
# 12838                      Drama, Fantasy, Slice of Life
# 12030                               Drama, Music, School
# 8813                Fantasy, Slice of Life, Supernatural
# 7536                      Comedy, Romance, Slice of Life
# 7325                  Comedy, Drama, Romance, Shounen Ai
# 9576                                               Music
# 9473        Comedy, Drama, School, Slice of Life, Sports
# 6291       Slice of Life, Comedy, Drama, Romance, School
# 8249                       Action, Supernatural, Fantasy
# 7937                Fantasy, Slice of Life, Supernatural
# 7179                                      Comedy, Sports
# 7010       Comedy, Drama, Romance, School, Slice of Life
# 6658       Comedy, Drama, Romance, School, Slice of Life
# 8592       Comedy, Drama, Romance, School, Slice of Life
# 7061       Comedy, Drama, Romance, School, Slice of Life
# 602     Romance, Supernatural, Comedy, Historical, Drama
# 6414                                      Comedy, School
# 12112                              Action, Sci-Fi, Mecha
# 7814                                              Comedy
# 7566                                      Comedy, School
# 7892                                              Comedy
# 12710                                             Comedy
# 12911              Drama, Romance, School, Slice of Life
# 6447                                       Action, Mecha
# 13380                                             Comedy
# 6835                                        Supernatural
# 15920                              Sports, Drama, School
#
#                                                 Synopsis     Type  Episodes  \
# 13608  Six months ago, Sakuta Azusagawa had a chance ...    Movie         1
# 13397  original sequel to the TV anime which aired in...    Movie         1
# 4286   One cold Christmas day, Kyon heads over to sch...    Movie         1
# 13439  It is not strange that the Demon Lord's forces...    Movie         1
# 12728  h the second Winter Comiket just around the co...    Movie         1
# 14511  Isabella, the daughter of the noble York famil...    Movie         1
# 13050  The rare and inexplicable Puberty Syndrome is ...       TV        13
# 5085   Graduation looms for the founding members of t...    Movie         1
# 10880  In ancient Disboard, Riku is an angry, young w...    Movie         1
# 12838  The CH Postal Company has just received a requ...  Special         1
# 12030  z's days of solitude come to an end when she m...    Movie         1
# 8813   fter Akihito Kanbara reunites with Mirai Kuriy...    Movie         1
# 7536   s she edges toward the end of her high school ...    Movie         1
# 7325   ovie adaptation of the Sekaiichi Hatsukoi: Yok...    Movie         1
# 9576   usic video Yakusoku no Kizuna from Kyoukai no ...  Special         1
# 9473   High☆Speed!: Free! Starting Days plunges into ...    Movie         1
# 6291   Everybody has had that stage in their life whe...       TV        12
# 8249   The first part of a two-part movie. The story ...    Movie         1
# 7937   Taking place three years before the TV series,...  Special         1
# 7179                  Specials bundled with the DVD/BDs.  Special         7
# 7010   The awkward lovebirds, Yuuta Togashi and Rikka...       TV        12
# 6658   lthough Yuuta Togashi and Rikka Takanashi have...  Special         1
# 8592   One normal school day, Rikka Takanashi notices...  Special         1
# 7061   Summary of the first season of the show, as se...    Movie         1
# 602    xtension of the summer-arc in the Air TV-serie...  Special         2
# 6414   Short episodes aired on KyoAni's official YouT...      ONA         6
# 12112  Yuuta Hibiki wakes up in the room of Rikka Tak...       TV        12
# 7814   Special episode included with the Blu-ray/DVD ...  Special         1
# 7566   Short episodes aired on KyoAni's official YouT...      ONA         6
# 7892   The charming cast consisting of Rikka Takanash...  Special         7
# 12710  No synopsis information has been added to this...      ONA        24
# 12911  In the late 90's, in China, Tu Xiaoyi, an high...    Movie         1
# 6447   Specials bundled with the 1st season's BD/DVD ...  Special         7
# 13380  Short theater manners shown before Chuunibyou ...    Movie         3
# 6835   Kyoto Animation commercial for the light novel...  Special         1
# 15920  ovie adaptation of Tsurune: Kazemai Koukou Kyu...    Movie         1
#
#          Premiered                 Studios        Source  \
# 13608      Unknown             CloverWorks   Light novel
# 13397      Unknown         Kyoto Animation   Light novel
# 4286       Unknown         Kyoto Animation   Light novel
# 13439      Unknown               J.C.Staff   Light novel
# 12728      Unknown             CloverWorks   Light novel
# 14511      Unknown         Kyoto Animation   Light novel
# 13050    Fall 2018             CloverWorks   Light novel
# 5085       Unknown         Kyoto Animation  4-koma manga
# 10880      Unknown                Madhouse   Light novel
# 12838      Unknown         Kyoto Animation   Light novel
# 12030      Unknown         Kyoto Animation         Novel
# 8813       Unknown         Kyoto Animation   Light novel
# 7536       Unknown         Kyoto Animation      Original
# 7325       Unknown             Studio Deen   Light novel
# 9576       Unknown         Kyoto Animation   Light novel
# 9473       Unknown         Kyoto Animation   Light novel
# 6291     Fall 2012         Kyoto Animation   Light novel
# 8249       Unknown         Kyoto Animation   Light novel
# 7937       Unknown         Kyoto Animation   Light novel
# 7179       Unknown         Kyoto Animation   Light novel
# 7010   Winter 2014         Kyoto Animation   Light novel
# 6658       Unknown         Kyoto Animation   Light novel
# 8592       Unknown         Kyoto Animation   Light novel
# 7061       Unknown         Kyoto Animation   Light novel
# 602        Unknown         Kyoto Animation  Visual novel
# 6414       Unknown         Kyoto Animation   Light novel
# 12112    Fall 2018                 Trigger      Original
# 7814       Unknown         Kyoto Animation   Light novel
# 7566       Unknown         Kyoto Animation   Light novel
# 7892       Unknown         Kyoto Animation   Light novel
# 12710      Unknown         Kyoto Animation       Unknown
# 12911      Unknown  Guton Animation Studio         Manga
# 6447       Unknown         Kyoto Animation   Light novel
# 13380      Unknown         Kyoto Animation       Unknown
# 6835       Unknown         Kyoto Animation   Light novel
# 15920      Unknown         Kyoto Animation   Light novel
#
#                           Rating  Ranked  Popularity  Favorites  \
# 13608  PG-13 - Teens 13 or older    46.0         370       6468
# 13397  PG-13 - Teens 13 or older    55.0         779        961
# 4286   PG-13 - Teens 13 or older    54.0         243      11585
# 13439  PG-13 - Teens 13 or older    98.0         321       3814
# 12728  PG-13 - Teens 13 or older   113.0        1567       1132
# 14511  PG-13 - Teens 13 or older   152.0         824        716
# 13050  PG-13 - Teens 13 or older   166.0          78      29642
# 5085   PG-13 - Teens 13 or older   202.0         607       2091
# 10880  PG-13 - Teens 13 or older   208.0         173       7022
# 12838  PG-13 - Teens 13 or older   211.0         832        494
# 12030  PG-13 - Teens 13 or older   295.0        1649       1439
# 8813   PG-13 - Teens 13 or older   313.0         795        946
# 7536   PG-13 - Teens 13 or older   537.0         590       1712
# 7325   PG-13 - Teens 13 or older   595.0        2234        227
# 9576   PG-13 - Teens 13 or older   688.0        2409         88
# 9473   PG-13 - Teens 13 or older   715.0        1872        260
# 6291   PG-13 - Teens 13 or older   878.0          77      17973
# 8249   PG-13 - Teens 13 or older   966.0        1233        255
# 7937   PG-13 - Teens 13 or older  1101.0        1451         65
# 7179   PG-13 - Teens 13 or older  1198.0        2031        137
# 7010   PG-13 - Teens 13 or older  1378.0         226       2952
# 6658   PG-13 - Teens 13 or older  1551.0         901        144
# 8592   PG-13 - Teens 13 or older  1672.0        1519         88
# 7061   PG-13 - Teens 13 or older  2109.0        1739        102
# 602    PG-13 - Teens 13 or older  2185.0        2649         44
# 6414   PG-13 - Teens 13 or older  2520.0        1306        176
# 12112  PG-13 - Teens 13 or older  2804.0         734        937
# 7814   PG-13 - Teens 13 or older  2840.0        3112          7
# 7566   PG-13 - Teens 13 or older  2901.0        1879         87
# 7892   PG-13 - Teens 13 or older  3142.0        2283         37
# 12710               G - All Ages  4242.0        4603         27
# 12911  PG-13 - Teens 13 or older  4626.0        5597          5
# 6447   PG-13 - Teens 13 or older  4788.0        1870         44
# 13380               G - All Ages  6257.0        5124         10
# 6835                G - All Ages  6679.0        4808          5
# 15920  PG-13 - Teens 13 or older     0.0        5825         15
#
#                                                 Features  \
# 13608  six months ago sakuta azusagawa chance encount...
# 13397  original sequel tv anime aired 2018 movie foll...
# 4286   one cold christmas day kyon heads school sos b...
# 13439  strange demon lords forces fear crimson demons...
# 12728  h second winter comiket around corner blessing...
# 14511  isabella daughter noble york family enrolled a...
# 13050  rare inexplicable puberty syndrome thought myt...
# 5085   graduation looms founding members light music ...
# 10880  ancient disboard riku angry young warrior inte...
# 12838  ch postal company received request transcribe ...
# 12030  zs days solitude come end meets blue bird form...
# 8813   fter akihito kanbara reunites mirai kuriyamawh...
# 7536   edges toward end high school life energetic ge...
# 7325   ovie adaptation sekaiichi hatsukoi yokozawa ta...
# 9576   usic video yakusoku kizuna kyoukai kanata movi...
# 9473   highspeed free starting days plunges past iwat...
# 6291   everybody stage life thought special different...
# 8249   first part twopart movie story recap tv series...
# 7937   taking place three years tv series episode zer...
# 7179   specials bundled dvd bds comedy sports free fr...
# 7010   awkward lovebirds yuuta togashi rikka takanash...
# 6658   lthough yuuta togashi rikka takanashi started ...
# 8592   one normal school day rikka takanashi notices ...
# 7061   summary first season show seen rikkas perspect...
# 602    xtension summerarc air tvseries showing happen...
# 6414   short episodes aired kyoanis official youtube ...
# 12112  yuuta hibiki wakes room rikka takarada notices...
# 7814   special episode included bluray dvd release ch...
# 7566   short episodes aired kyoanis official youtube ...
# 7892   charming cast consisting rikka takanashi frien...
# 12710  synopsis information added title help improve ...
# 12911  late 90s china tu xiaoyi high school student t...
# 6447   specials bundled 1st seasons bd dvd volumes ac...
# 13380  short theater manners shown chuunibyou demo ko...
# 6835   kyoto animation commercial light novel series ...
# 15920  ovie adaptation tsurune kazemai koukou kyuudou...
#
#                                               name_lower
# 13608  seishun buta yarou wa yumemiru shoujo no yume ...
# 13397                            violet evergarden movie
# 4286                       suzumiya haruhi no shoushitsu
# 13439  kono subarashii sekai ni shukufuku wo!: kurena...
# 12728                  saenai heroine no sodatekata fine
# 14511  violet evergarden gaiden: eien to jidou shuki ...
# 13050  seishun buta yarou wa bunny girl senpai no yum...
# 5085                                         k-on! movie
# 10880                              no game no life: zero
# 12838  violet evergarden: kitto "ai" wo shiru hi ga k...
# 12030                                    liz to aoi tori
# 8813   kyoukai no kanata movie 2: i'll be here - mira...
# 7536                                   tamako love story
# 7325   sekaiichi hatsukoi movie: yokozawa takafumi no...
# 9576   kyoukai no kanata movie: i'll be here - kako-h...
# 9473                    high☆speed!: free! starting days
# 6291                      chuunibyou demo koi ga shitai!
# 8249   kyoukai no kanata movie 1: i'll be here - kako...
# 7937                        kyoukai no kanata: shinonome
# 7179                           free!: frfr - short movie
# 7010                  chuunibyou demo koi ga shitai! ren
# 6658   chuunibyou demo koi ga shitai!: kirameki no......
# 8592   chuunibyou demo koi ga shitai! ren: the rikka ...
# 7061   takanashi rikka kai: chuunibyou demo koi ga sh...
# 602                                        air in summer
# 6414                 chuunibyou demo koi ga shitai! lite
# 12112                                       ssss.gridman
# 7814   takanashi rikka kai: chuunibyou demo koi ga sh...
# 7566             chuunibyou demo koi ga shitai! ren lite
# 7892         chuunibyou demo koi ga shitai! ren specials
# 12710  chuunibyou demo koi ga shitai! movie: take on ...
# 12911                                    zuori qing kong
# 6447   chuunibyou demo koi ga shitai!: depth of field...
# 13380  chuunibyou demo koi ga shitai! movie: take on ...
# 6835                         kyoto animation: megane-hen
# 15920            tsurune: kazemai koukou kyuudoubu movie
