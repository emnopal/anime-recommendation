# %%
import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix, load_npz
from sklearn.neighbors import NearestNeighbors

# %%
anime = pd.read_csv("../data/datasets/anime_clean.csv")
anime_metadata = np.load("../data/binary/anime_metadata.npy")
animeFeaturesTfidf = load_npz("../data/binary/animeFeaturesTfidf.npz")

# %%
def animeSearch(df_, nameQuery, n=5, sortByScore=True):
    df = df_.copy()
    nameQuery = nameQuery.lower()
    df["name_lower"] = df["Name"].apply(lambda x: x.lower())

    nameContains = df.loc[df.name_lower.str.contains(nameQuery, na=False)].drop(columns=['Features',
                                                                                         'name_lower'])

    if sortByScore:
        nameContains = nameContains.sort_values(by="Score", ascending=False)

    if n in ['all', 'All']:
        pd.set_option('display.max_rows', len(nameContains))
    else:
        pd.set_option('display.max_rows', n)
        nameContains = nameContains[:n]
        return nameContains
    return nameContains


def getSimilar(df=anime, vector=None, query_index=None, n=50):
    model_knn = NearestNeighbors(metric='cosine', n_neighbors=n)
    model_knn.fit(csr_matrix(vector.astype(np.float)))

    distances, indices = model_knn.kneighbors(
        vector[query_index, :].reshape(1, -1), n_neighbors=n)
    result, score = [], []
    for i in range(0, len(distances.flatten())):
        index = indices.flatten()[i]
        if index == query_index:
            continue
        result.append(df.iloc[index])
    results_df = pd.DataFrame(result)#.sort_values(by="Score", ascending=False)
    pd.set_option('display.max_rows', len(results_df))
    return results_df


def mostSimilarByIndex(query_index, n=50, showAll=True):
    vectorMeta = anime_metadata
    vectorSynop = animeFeaturesTfidf
    Meta = getSimilar(
        df=anime, vector=vectorMeta, query_index=query_index, n=n)
    Synop = getSimilar(
        df=anime, vector=vectorSynop, query_index=query_index, n=n)
    MetaSynop = Synop.append(Meta)
    MetaSynop = MetaSynop.drop_duplicates().sort_values(by="Score", ascending=False)
    MetaSynop = MetaSynop.drop(columns=['Features'])
    if showAll:
        pd.set_option('display.max_rows', len(MetaSynop))
        print(
            f"Generated total dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
        return MetaSynop
    pd.set_option('display.max_rows', 10)
    print(
        f"Generated dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
    return MetaSynop

def mostSimilarByName(name, n=50, showAll=True):
    query = animeSearch(nameQuery=name, df_=anime, n=1, sortByScore=False)
    query_index = query.index
    vectorMeta = anime_metadata
    vectorSynop = animeFeaturesTfidf
    Meta = getSimilar(
        df=anime, vector=vectorMeta, query_index=query_index, n=n)
    Synop = getSimilar(
        df=anime, vector=vectorSynop, query_index=query_index, n=n)
    MetaSynop = Synop.append(Meta)
    MetaSynop = MetaSynop.drop_duplicates().sort_values(by="Score", ascending=False)
    MetaSynop = MetaSynop.drop(columns=['Features'])
    if showAll:
        pd.set_option('display.max_rows', len(MetaSynop))
        print(
            f"Generated total dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
        return query, MetaSynop
    pd.set_option('display.max_rows', 10)
    print(
        f"Generated dataframe with {MetaSynop.shape[0]} rows and {MetaSynop.shape[1]} columns")
    return query, MetaSynop

# %%
animeResults = animeSearch(anime, nameQuery="Jojo", n=1)
animeResults
# Out:
#        MAL_ID            Name  Score                                Genres  \
# 10213   32281  Kimi no Na wa.   8.96  Romance, Supernatural, School, Drama
#
#                                                 Synopsis   Type  Episodes  \
# 10213  suha Miyamizu, a high school girl, yearns to l...  Movie         1
#
#       Premiered           Studios    Source                     Rating  \
# 10213   Unknown  CoMix Wave Films  Original  PG-13 - Teens 13 or older
#
#        Ranked  Popularity  Favorites
# 10213    16.0          11    1726660

# %%
testa, testb = mostSimilarByName('Jojo', n=20)
# Out:
# Generated total dataframe with 36 rows and 15 columns

# %%
testa
# Out:
#      MAL_ID                                 Name  Score  \
# 608     665  JoJo no Kimyou na Bouken: Adventure   7.18
#
#                                                 Genres  \
# 608  Adventure, Drama, Fantasy, Horror, Shounen, Su...
#
#                                               Synopsis Type  Episodes  \
# 608  Kujo Jotaro is a normal, popular Japanese high...  OVA         7
#
#     Premiered Studios Source            Rating  Ranked  Popularity  Favorites
# 608   Unknown    APPP  Manga  R+ - Mild Nudity  2855.0        2102      55986

# %%
testb.head(1)
# Out:
#        MAL_ID                                            Name  Score  \
# 13401   37991  JoJo no Kimyou na Bouken Part 5: Ougon no Kaze   8.61
#
#                            Genres  \
# 13401  Action, Adventure, Shounen
#
#                                                 Synopsis Type  Episodes  \
# 13401  In the coastal city of Naples, corruption is t...   TV        39
#
#        Premiered           Studios Source                          Rating  \
# 13401  Fall 2018  David Production  Manga  R - 17+ (violence & profanity)
#
#        Ranked  Popularity  Favorites  \
# 13401    63.0         211     542642
#
#                                            name_lower
# 13401  jojo no kimyou na bouken part 5: ougon no kaze

# %%
testb['Score'][13401].astype('object')
# Out:
# 8.61

# %%
testb.to_dict(orient='list')
# Out:
# {'MAL_ID': [37991,
#   31933,
#   26055,
#   20899,
#   14719,
#   268,
#   3603,
#   9201,
#   7762,
#   31380,
#   1913,
#   32485,
#   666,
#   822,
#   13055,
#   11313,
#   201,
#   32698,
#   35000,
#   2354,
#   1556,
#   151,
#   1016,
#   3121,
#   36950,
#   15933,
#   38972,
#   8211,
#   8146,
#   11005,
#   5648,
#   16954,
#   2384,
#   730,
#   24087,
#   24085],
#  'Name': ['JoJo no Kimyou na Bouken Part 5: Ougon no Kaze',
#   'JoJo no Kimyou na Bouken Part 4: Diamond wa Kudakenai',
#   'JoJo no Kimyou na Bouken Part 3: Stardust Crusaders 2nd Season',
#   'JoJo no Kimyou na Bouken Part 3: Stardust Crusaders',
#   'JoJo no Kimyou na Bouken (TV)',
#   'Golden Boy',
#   'JoJo no Kimyou na Bouken: Phantom Blood',
#   'Air Gear: Kuro no Hane to Nemuri no Mori - Break on the Sky',
#   'Yondemasu yo, Azazel-san.',
#   'To LOVE-Ru Darkness 2nd OVA',
#   'Shonan Junai Gumi!',
#   'Prison School: Mad Wax',
#   'JoJo no Kimyou na Bouken',
#   'Initial D Extra Stage',
#   'Sankarea OVA',
#   'Kimi no Iru Machi: Tasogare Kousaten',
#   'Video Girl Ai',
#   'Monster Musume no Iru Nichijou OVA',
#   'To LOVE-Ru: Multiplication - Mae kara Ushiro kara',
#   'Devilman: Tanjou-hen',
#   'Kikoushi Enma',
#   'Re: Cutey Honey',
#   'Gunnm',
#   'Kodomo no Jikan OVA',
#   'Yuragi-sou no Yuuna-san OVA',
#   'Vassalord.',
#   'JoJo no Kimyou na Bouken Part 5: Ougon no Kaze Recaps',
#   'Dance in the Vampire Bund: Special Edition',
#   'Gegege no Kitarou: Daikaijuu',
#   'Holy Knight',
#   'Bouken Shite mo Ii Koro',
#   'Milky Passion: Dougenzaka - Ai no Shiro',
#   'Yakusai Kochou',
#   'Houkago no Shokuinshitsu',
#   'Be-Bop Kaizokuban',
#   'Shura ga Yuku'],
#  'Score': [8.61,
#   8.51,
#   8.45,
#   8.12,
#   8.06,
#   8.03,
#   7.71,
#   7.62,
#   7.6,
#   7.57,
#   7.48,
#   7.46,
#   7.35,
#   7.33,
#   7.25,
#   7.23,
#   7.21,
#   7.19,
#   7.17,
#   7.15,
#   7.13,
#   7.12,
#   7.09,
#   7.09,
#   7.08,
#   6.85,
#   6.74,
#   6.55,
#   6.22,
#   6.02,
#   5.53,
#   5.44,
#   5.37,
#   5.15,
#   0.0,
#   0.0],
#  'Genres': ['Action, Adventure, Shounen',
#   'Action, Adventure, Comedy, Supernatural, Drama, Shounen',
#   'Action, Adventure, Supernatural, Drama, Shounen',
#   'Action, Adventure, Supernatural, Drama, Shounen',
#   'Action, Adventure, Supernatural, Vampire, Shounen',
#   'Adventure, Comedy, Ecchi',
#   'Action, Adventure, Horror, Shounen, Vampire',
#   'Action, Comedy, Ecchi, Shounen, Sports',
#   'Comedy, Demons, Supernatural',
#   'Sci-Fi, Harem, Comedy, Romance, Ecchi, School, Shounen',
#   'Action, Comedy, School',
#   'Comedy, Romance, Ecchi, School, Seinen',
#   'Adventure, Drama, Fantasy, Horror, Shounen, Supernatural, Vampire',
#   'Action, Cars, Sports, Drama, Seinen',
#   'Comedy, Ecchi, Horror, Romance, Shounen, Supernatural',
#   'Drama, Romance, School, Shounen',
#   'Comedy, Drama, Ecchi, Romance',
#   'Comedy, Ecchi, Fantasy, Harem, Romance, Seinen',
#   'Comedy, Ecchi, Harem, Romance, School, Sci-Fi, Shounen',
#   'Demons, Horror, Sci-Fi, Supernatural',
#   'Horror, Demons, Supernatural, Magic, Ecchi, Fantasy, Seinen',
#   'Action, Sci-Fi, Comedy, Ecchi, Shoujo Ai',
#   'Drama, Mecha, Sci-Fi, Shounen',
#   'Comedy, Ecchi, School',
#   'Harem, Comedy, Supernatural, Romance, Ecchi, Shounen',
#   'Action, Comedy, Fantasy, Mystery, Shounen Ai, Supernatural, Vampire',
#   'Action, Adventure, Shounen',
#   'Action, Supernatural, Vampire',
#   'Action, Fantasy, Horror, Shounen, Supernatural',
#   'Ecchi, Fantasy, Supernatural, School, Vampire, Seinen',
#   'Comedy, Seinen',
#   'Romance, Josei',
#   'Comedy, Supernatural, Ecchi',
#   'Drama, Romance, Shounen Ai',
#   'Comedy, School, Seinen',
#   'Drama, Seinen'],
#  'Synopsis': ['In the coastal city of Naples, corruption is teeming—the police blatantly conspire with outlaws, drugs run rampant around the youth, and the mafia governs the streets with an iron fist. However, various fateful encounters will soon occur. Enter Giorno Giovanna, a 15-year-old boy with an eccentric connection to the Joestar family, who makes a living out of part-time jobs and pickpocketing. Furthermore, he is gifted with the unexplained Stand ability to give and create life—growing plants from the ground and turning inanimate objects into live animals, an ability he has dubbed "Gold Experience." Fascinated by the might of local gangsters, Giorno has dreamed of rising up in their ranks and becoming a "Gang-Star," a feat made possible by his encounter with Bruno Buccellati, a member of the Passione gang with his own sense of justice. JoJo no Kimyou na Bouken: Ougon no Kaze follows the endeavors of Giorno after joining Bruno\'s team while working under Passione, fending off other gangsters and secretly plotting to overthrow their mysterious boss.',
#   "series of OVA episodes released with the limited edition manga volumes. Episode 01: What You Gave Me (Anata ga Watashi ni Kureta Mono) Kokonoe, Usa, and Kagami go shopping for a present for Sensei. Eventually Kokonoe decides to make one and they all end up spending the night at her house. Along the way we learn more about Usa's love for Reiji, Kagami's love for Kokonoe, and Kokonoe's love for Sensei. Episode 02: Kuro-chan, Shiro-chan (Kuro-chan to Shiro-chan) Kuro-chan tries to become friends with Shirai-sensei. Episode 03: A Child's Summer Time (Kodomo no Natsu Jikan) The girls, Aoki and Houin go into the country to visit Aoki's family.",
#   'Bundled with the 11th, 12th, 13th and 24th volumes of the Yuragi-sou no Yuuna-san manga. The first episode will adapt the manga\'s 12th chapter. The last OVA will adapt the 99th chapter of the manga, "Noroware no Kogarashi," and the 141st chapter, "Giri Giri!? Onsen Happening."',
#   "Charley, a cyborg vampire who does the Vatican's dirty work, is the thrall of the local vampire playboy Johnny Rayflo. As the two fight crime—and each other—hilarity, violence and sacrilege ensue! But can Charley resist his own desperate cravings for blood? Find out as the devilish duo go up against a childlike vampire princess, a mysterious branch of the Unitarian Church...and one another. (Source: Tokyopop)",
#   'caps of the JoJo no Kimyou na Bouken: Ougon no Kaze series.',
#   'Dance in the Vampire Bund recap episode featuring re-edited footage from the first 7 episodes.',
#   'ovie based on the 1996 TV anime with an original plot.',
#   'The story centers around a timid orphan named Mizumura Shinta who goes to a missionary school in Tokyo. His seemingly normal life changes when a beautiful half-human Romanian girl named Lilith suddenly transfers into his school. Mizumura discovers that he is actually a vampire hunter and the successor of the Romuald lineage. (Source: ANN)',
#   'Follow a cast that makes pornographic movies. The loves and loyalty it creates and the friction it causes. (Source: AniDB)',
#   'Based on the Milky Passion manga by Morizono Milk.',
#   "Spirits begin terrorizing a school and it is left up to the sexy student Kocho Enoki to use her attractive body and magical powers to defeat the attackers. Teamed with her sister and Kosaku, their human decoy, they attempt to free the school from the spirits. Unfortunately a female spirit arrives who is immune to Kocho's sexy charms. (Source: ANN)",
#   'Two teachers and their ups and downs of being in love with each other.',
#   'Based on a parody manga of Be-Bop Highschool.',
#   'Based on a Yakuza drama manga by Kawabe Yuu and Yamaguchi Masato.'],
#  'Type': ['TV',
#   'TV',
#   'TV',
#   'TV',
#   'TV',
#   'OVA',
#   'Movie',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'Special',
#   'Special',
#   'Movie',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA',
#   'OVA'],
#  'Episodes': [39,
#   39,
#   24,
#   24,
#   26,
#   6,
#   1,
#   3,
#   4,
#   3,
#   5,
#   1,
#   6,
#   2,
#   2,
#   2,
#   6,
#   2,
#   1,
#   1,
#   4,
#   3,
#   2,
#   3,
#   4,
#   1,
#   3,
#   1,
#   1,
#   2,
#   3,
#   1,
#   1,
#   2,
#   3,
#   2],
#  'Premiered': ['Fall 2018',
#   'Spring 2016',
#   'Winter 2015',
#   'Spring 2014',
#   'Fall 2012',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown'],
#  'Studios': ['David Production',
#   'David Production',
#   'David Production',
#   'David Production',
#   'David Production',
#   'APPP',
#   'APPP',
#   'Satelight',
#   'Production I.G',
#   'Xebec',
#   'J.C.Staff, Life Work',
#   'J.C.Staff',
#   'APPP',
#   'Pastel',
#   'Studio Deen',
#   'Tatsunoko Production',
#   'Production I.G',
#   'Lerche',
#   'Xebec',
#   'Oh! Production',
#   "Brain's Base",
#   'Gainax, Toei Animation',
#   'Madhouse',
#   'Diomedéa',
#   'Xebec',
#   'Production I.G',
#   'David Production',
#   'Shaft',
#   'Toei Animation',
#   'Lilix',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Unknown',
#   'Toei Animation',
#   'Unknown'],
#  'Source': ['Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Unknown',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga',
#   'Manga'],
#  'Rating': ['R - 17+ (violence & profanity)',
#   'R - 17+ (violence & profanity)',
#   'R - 17+ (violence & profanity)',
#   'R - 17+ (violence & profanity)',
#   'R - 17+ (violence & profanity)',
#   'R+ - Mild Nudity',
#   'R - 17+ (violence & profanity)',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R - 17+ (violence & profanity)',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R - 17+ (violence & profanity)',
#   'R - 17+ (violence & profanity)',
#   'R+ - Mild Nudity',
#   'G - All Ages',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity',
#   'R+ - Mild Nudity'],
#  'Ranked': [63.0,
#   100.0,
#   122.0,
#   390.0,
#   463.0,
#   507.0,
#   1000.0,
#   1207.0,
#   1271.0,
#   1361.0,
#   1650.0,
#   1711.0,
#   2110.0,
#   2220.0,
#   2556.0,
#   2652.0,
#   2725.0,
#   2831.0,
#   2918.0,
#   2986.0,
#   3093.0,
#   3130.0,
#   3253.0,
#   3262.0,
#   3288.0,
#   4249.0,
#   4720.0,
#   5634.0,
#   7244.0,
#   8142.0,
#   9605.0,
#   9850.0,
#   10005.0,
#   10392.0,
#   13403.0,
#   12074.0],
#  'Popularity': [211,
#   163,
#   159,
#   136,
#   74,
#   579,
#   2403,
#   2045,
#   3133,
#   1934,
#   2730,
#   1326,
#   1731,
#   2718,
#   1528,
#   2637,
#   3409,
#   1678,
#   2911,
#   3498,
#   3880,
#   3430,
#   2370,
#   3129,
#   2589,
#   3103,
#   3350,
#   4307,
#   10779,
#   2653,
#   10478,
#   11668,
#   9029,
#   5802,
#   11625,
#   14591],
#  'Favorites': [542642,
#   625022,
#   641298,
#   694803,
#   965386,
#   251683,
#   44881,
#   58081,
#   27352,
#   63685,
#   35277,
#   106314,
#   75346,
#   35581,
#   90529,
#   37372,
#   23075,
#   79644,
#   31119,
#   22009,
#   17516,
#   22697,
#   45987,
#   27427,
#   38700,
#   27890,
#   23996,
#   13798,
#   863,
#   36748,
#   998,
#   612,
#   1871,
#   6568,
#   616,
#   218],
#  'name_lower': ['jojo no kimyou na bouken part 5: ougon no kaze',
#   'jojo no kimyou na bouken part 4: diamond wa kudakenai',
#   'jojo no kimyou na bouken part 3: stardust crusaders 2nd season',
#   'jojo no kimyou na bouken part 3: stardust crusaders',
#   'jojo no kimyou na bouken (tv)',
#   'golden boy',
#   'jojo no kimyou na bouken: phantom blood',
#   'air gear: kuro no hane to nemuri no mori - break on the sky',
#   'yondemasu yo, azazel-san.',
#   'to love-ru darkness 2nd ova',
#   'shonan junai gumi!',
#   'prison school: mad wax',
#   'jojo no kimyou na bouken',
#   'initial d extra stage',
#   'sankarea ova',
#   'kimi no iru machi: tasogare kousaten',
#   'video girl ai',
#   'monster musume no iru nichijou ova',
#   'to love-ru: multiplication - mae kara ushiro kara',
#   'devilman: tanjou-hen',
#   'kikoushi enma',
#   're: cutey honey',
#   'gunnm',
#   'kodomo no jikan ova',
#   'yuragi-sou no yuuna-san ova',
#   'vassalord.',
#   'jojo no kimyou na bouken part 5: ougon no kaze recaps',
#   'dance in the vampire bund: special edition',
#   'gegege no kitarou: daikaijuu',
#   'holy knight',
#   'bouken shite mo ii koro',
#   'milky passion: dougenzaka - ai no shiro',
#   'yakusai kochou',
#   'houkago no shokuinshitsu',
#   'be-bop kaizokuban',
#   'shura ga yuku']}

# %%
testing = {
    'anime': {},
    'similar': {}
}
ab = []
for i in testb.columns:
    an = []
    for j in testb.index:
        an.append(anime.loc[j,i])
    ab.append(an)
    testing['similar'][i] = ab[-1]

ab = []
for i in testa.columns:
    an = []
    for j in testa.index:
        an.append(anime.loc[j,i])
    ab.append(an)
    testing['anime'][i] = ab[-1]

# %%
mostSimilarByIndex(query_index=10213, n=20)
# Out:
# Generated total dataframe with 33 rows and 14 columns
#        MAL_ID                                               Name  Score  \
# 11021   33902                   Suntory Minami Alps no Tennensui   6.00
# 15772   42785                                         Hadakanbou   0.00
# 13906   38826                                        Tenki no Ko   8.41
# 13015   37396                                        Shikioriori   7.17
# 1470     1689                              Byousoku 5 Centimeter   7.73
# 8284    25143                 Kono Danshi, Sekka ni Nayandemasu.   6.97
# 6086    13283                                            One Off   6.44
# 7808    22839                                         Cross Road   7.40
# 5127     9760                                 Hoshi wo Ou Kodomo   7.58
# 6688    17121                                Dareka no Manazashi   7.39
# 10381   32734                   Satto Anshin, SAT x Peeping Life   0.00
# 6619    16782                                   Kotonoha no Niwa   8.05
# 7233    19925                               KY-kei JC Kuuki-chan   5.48
# 1086     1220                                   Hoshizora Kiseki   5.80
# 6594    16690                                            My Life   6.33
# 224       256                                       Hoshi no Koe   7.22
# 15763   42762                               Happy Happy Birthday   0.00
# 15276   41250                     Oshiete Hokusai! The Animation   0.00
# 2460     2931                                              Mokke   7.07
# 395       433                   Kumo no Mukou, Yakusoku no Basho   7.56
# 142       164                                      Mononoke Hime   8.72
# 3646     5681                                        Summer Wars   8.09
# 2351     2759                Evangelion: 1.0 You Are (Not) Alone   8.07
# 2918     3784              Evangelion: 2.0 You Can (Not) Advance   8.35
# 8839    28805                                     Bakemono no Ko   8.33
# 5829    11981  Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...   8.44
# 12115   35851     Sayonara no Asa ni Yakusoku no Hana wo Kazarou   8.45
# 6254    14349                              Little Witch Academia   7.85
# 7536    21647                                  Tamako Love Story   8.00
# 2919     3785                 Evangelion: 3.0 You Can (Not) Redo   7.59
# 8827    28725                      Kokoro ga Sakebitagatterunda.   7.96
# 5921    12477                                 Sakasama no Patema   8.05
# 6326    15039  Ano Hi Mita Hana no Namae wo Bokutachi wa Mada...   7.95
#
#                                                Genres  \
# 11021                                   Drama, School
# 15772                                     Kids, Music
# 13906          Slice of Life, Drama, Romance, Fantasy
# 13015                   Drama, Romance, Slice of Life
# 1470                    Drama, Romance, Slice of Life
# 8284                        Drama, School, Shounen Ai
# 6086                                    Slice of Life
# 7808                            Slice of Life, School
# 5127                      Adventure, Romance, Fantasy
# 6688                             Drama, Slice of Life
# 10381                           Comedy, Slice of Life
# 6619     Slice of Life, Psychological, Drama, Romance
# 7233                                   Comedy, School
# 1086                                  Romance, Sci-Fi
# 6594                             Slice of Life, Drama
# 224              Sci-Fi, Space, Drama, Romance, Mecha
# 15763                                     Kids, Music
# 15276                  Slice of Life, Comedy, Fantasy
# 2460             Slice of Life, Supernatural, Mystery
# 395                  Drama, Military, Romance, Sci-Fi
# 142                        Action, Adventure, Fantasy
# 3646                                   Sci-Fi, Comedy
# 2351      Action, Sci-Fi, Psychological, Drama, Mecha
# 2918      Action, Sci-Fi, Psychological, Drama, Mecha
# 8839                          Adventure, Supernatural
# 5829   Mystery, Psychological, Drama, Magic, Thriller
# 12115                                  Drama, Fantasy
# 6254        Adventure, Comedy, Magic, Fantasy, School
# 7536                   Comedy, Romance, Slice of Life
# 2919      Action, Sci-Fi, Psychological, Drama, Mecha
# 8827                           Drama, Romance, School
# 5921                                Adventure, Sci-Fi
# 6326               Slice of Life, Supernatural, Drama
#
#                                                 Synopsis     Type  Episodes  \
# 11021  Collaboration commercials with Suntory and Kim...  Special         3
# 15772  usic video for the song Hadakanbou by Rumi Shi...    Music         1
# 13906  Tokyo is currently experiencing rain showers t...    Movie         1
# 13015  The rigorous city life of China, while bustlin...    Movie         3
# 1470   hat happens when two people love each other bu...    Movie         3
# 8284   umu Tamari suffers from a condition known as "...      OVA         1
# 6086   slice of life of high school girls in the earl...      OVA         4
# 7808   s college entrance examinations draw near, two...  Special         1
# 5127   If you could turn all your memories into a son...    Movie         1
# 6688   In near-future Japan, Aya Okamura lives alone ...    Movie         1
# 10381  SAT (Union Forest Company's Security division)...      ONA         3
# 6619   On a rainy morning in Tokyo, Takao Akizuki, an...    Movie         1
# 7233   On the first day as a transfer student, Betao ...      ONA         6
# 1086   Kozue is a girl who loves astronomy, particula...      ONA         1
# 6594   high school girl, while pondering her future, ...      ONA         1
# 224    It is the year 2046, Noboru Terao and Mikako N...      OVA         1
# 15763  usic video for the song Happy Happy Birthday b...    Music         1
# 15276  Tenkorin Okakura is a high school slacker girl...      ONA        10
# 2460   This is a story about two sisters: Shizuru, is...       TV        24
# 395    Hiroki Fujisawa and Takuya Shirakawa harbor ad...    Movie         1
# 142    hen an Emishi village is attacked by a fierce ...    Movie         1
# 3646   OZ, a virtual world connected to the internet,...    Movie         1
# 2351   In a post-apocalyptic world, the last remainin...    Movie         1
# 2918   hen the threat of the Angel menace escalates, ...    Movie         1
# 8839   Two souls, living very different lives, wander...    Movie         1
# 5829   The young girls of Mitakihara happily live the...    Movie         1
# 12115  aquia is a member of a special race called the...    Movie         1
# 6254   For young witches everywhere, the world-renown...    Movie         1
# 7536   s she edges toward the end of her high school ...    Movie         1
# 2919   Fourteen years after the Third Impact, the Ear...    Movie         1
# 8827   Jun Naruse is a chatterbox whose life is color...    Movie         1
# 5921   Patema is a plucky young girl from an undergro...    Movie         1
# 6326   ar after their deceased friend Honma Meiko app...    Movie         1
#
#        Premiered                                Studios     Source  \
# 11021    Unknown                                Unknown   Original
# 15772    Unknown                       CoMix Wave Films   Original
# 13906    Unknown                       CoMix Wave Films   Original
# 13015    Unknown                       CoMix Wave Films   Original
# 1470     Unknown                       CoMix Wave Films   Original
